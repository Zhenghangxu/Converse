# %% [markdown]
# ## Section 1: Fetch Drugs Detail from FDA and Save it into one JSON file
# ### Step 1: Mount drive and import (this one use google drive)

# %%
import requests
import zipfile
import io
import os
import json
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### Step 2: Def the download function

# %%
def download_and_extract_json(urls, output_dir="json_files"):
    # Create the output directory if it doesn't exist
    if not os.path.exists(output_dir):
        os.makedirs(output_dir)

    json_files = []

    for url in urls:
        try:
            # Download the zip file
            response = requests.get(url)
            response.raise_for_status()  # Check for HTTP errors

            # Unzip the downloaded file
            with zipfile.ZipFile(io.BytesIO(response.content)) as z:
                for file_name in z.namelist():
                    if file_name.endswith('.json'):
                        # Extract the JSON file
                        json_content = z.read(file_name)
                        json_data = json.loads(json_content)

                        # Save the JSON file
                        json_path = os.path.join(output_dir, file_name)
                        with open(json_path, 'w') as json_file:
                            json.dump(json_data, json_file, indent=4)
                        json_files.append(json_path)

                        print(f"Downloaded and extracted: {file_name}")

        except requests.exceptions.RequestException as e:
            print(f"Failed to download {url}: {e}")
        except zipfile.BadZipFile as e:
            print(f"Failed to unzip file from {url}: {e}")
        except json.JSONDecodeError as e:
            print(f"Failed to parse JSON from {url}: {e}")

    return json_files

# %% [markdown]
# ### Step 3: Start Download

# %%
# Example usage
urls = [
    'https://download.open.fda.gov/drug/label/drug-label-0001-of-0012.json.zip',
    'https://download.open.fda.gov/drug/label/drug-label-0002-of-0012.json.zip',
    'https://download.open.fda.gov/drug/label/drug-label-0003-of-0012.json.zip',
    'https://download.open.fda.gov/drug/label/drug-label-0004-of-0012.json.zip',
    'https://download.open.fda.gov/drug/label/drug-label-0005-of-0012.json.zip',
    'https://download.open.fda.gov/drug/label/drug-label-0006-of-0012.json.zip',
    'https://download.open.fda.gov/drug/label/drug-label-0007-of-0012.json.zip',
    'https://download.open.fda.gov/drug/label/drug-label-0008-of-0012.json.zip',
    'https://download.open.fda.gov/drug/label/drug-label-0009-of-0012.json.zip',
    'https://download.open.fda.gov/drug/label/drug-label-0010-of-0012.json.zip',
    'https://download.open.fda.gov/drug/label/drug-label-0011-of-0012.json.zip',
    'https://download.open.fda.gov/drug/label/drug-label-0012-of-0012.json.zip'


    # Add more URLs as needed
]

output_dir = '/content/drive/MyDrive/FDA_Data_Set'
os.makedirs(output_dir, exist_ok=True)

downloaded_json_files = download_and_extract_json(urls,output_dir=output_dir)
# Out:
# Downloaded and extracted: drug-label-0001-of-0012.json
# Downloaded and extracted: drug-label-0002-of-0012.json
# Downloaded and extracted: drug-label-0003-of-0012.json
# Downloaded and extracted: drug-label-0004-of-0012.json
# Downloaded and extracted: drug-label-0005-of-0012.json
# Downloaded and extracted: drug-label-0006-of-0012.json
# Downloaded and extracted: drug-label-0007-of-0012.json
# Downloaded and extracted: drug-label-0008-of-0012.json
# Downloaded and extracted: drug-label-0009-of-0012.json
# Downloaded and extracted: drug-label-0010-of-0012.json
# Downloaded and extracted: drug-label-0011-of-0012.json
# Downloaded and extracted: drug-label-0012-of-0012.json

# %% [markdown]
# ### Step 4: Ask LLM to Extra the Most Important JSON Properties:
#
# #### Prompt:
# ```
# This is a JSON object for a drug label. Say if you are a regular drug user, what would the the top 10 items you are most interested in?
# Output should follow this JSON format, for example
# { description: "manufacturer", property: "openfda.manufacturer_name"}
# ```
# ####File Input (Single JSON object)
#
# https://www.icloud.com/attachment/?u=https%3A%2F%2Fcvws.icloud-content.com%2FB%2FARW0mK0u5NMVvgWPKpruotC21r0FARStkgPOxx-tDwA6zw_MKccSeSmZ%2F%24%7Bf%7D%3Fo%3DAmXWpsdRZ_s3-1Ka3DxM39V0tZ0wfYrg4UDXRjAcLWSC%26v%3D1%26x%3D3%26a%3DCAogrUaKeKFBzAU-K1panPWpjKqei45e4Zo0jgG5ZilphxcSbxCy0vCrmDIYsuLr_6EyIgEAUgS21r0FWgQSeSmZaidJxGCo1JYtduGCwtBKepEj-YsAIU3YjuFh8OOeNLrCWscCdyLAjq1yJ52I9nsfL8D_GS21vc9Mu1z4oqxLUPGmM2CYRPJi6v9wKQSlir6-Kw%26e%3D1727113392%26fl%3D%26r%3DCDD5711F-E306-41A5-948C-7E730424ED8C-1%26k%3D%24%7Buk%7D%26ckc%3Dcom.apple.clouddocs%26ckz%3DiCloud.me.damir.dropover-mac%26p%3D140%26s%3DCBVbwaUrWC6v0w7EOhg07-C3k0g&uk=oDsC6nvo0z2mC_HJiFMXCw&f=singleJSON_Template.docx&sz=47205
#
# #### Output
# ```
# [
#     { "description": "Drug Name", "property": "openfda.brand_name" },
#     { "description": "Generic Name", "property": "openfda.generic_name" },
#     { "description": "Manufacturer", "property": "openfda.manufacturer_name" },
#     { "description": "Active Ingredients", "property": "active_ingredient" },
#     { "description": "Purpose", "property": "purpose" },
#     { "description": "Indications and Usage", "property": "indications_and_usage" },
#     { "description": "Dosage and Administration", "property": "dosage_and_administration" },
#     { "description": "Warnings", "property": "warnings" },
#     { "description": "Adverse Reactions", "property": "adverse_reactions" },
#     { "description": "Storage Information", "property": "storage_and_handling" }
# ]
# ```

# %% [markdown]
# ### Step 5: Start Extrating Info from JSONs

# %%
import os
import json
from typing import List

# Define the properties to extract
curated_properties = [
    { "description": "Drug_Name", "property": "openfda.brand_name" },
    { "description": "ID", "property": "id" },
    { "description": "Manufacturer", "property": "openfda.manufacturer_name" },
    { "description": "Purpose", "property": "purpose" },
    { "description": "Indications_and_Usage", "property": "indications_and_usage" },
    { "description": "Active_Ingredients", "property": "active_ingredient" },
    { "description":"do_not_USE","property":"do_not_use"},
    {"description":"STOP_USE","property":"stop_use"},
    {"description":"DOSAGE_INSTRUCTION","property":"dosage_and_administration"},
    { "description": "Storage_Information", "property": "storage_and_handling" },
    { "description": "Ask_Doctor", "property": "ask_doctor" },
]

# Define the search and match list
contain = ["HUMAN OTC DRUG"]

def flatten_json(y):
    """Flatten a nested JSON object into a single string."""
    out = []

    def flatten(x, name=''):
        if isinstance(x, dict):
            for a in x:
                flatten(x[a], name + a + '_')
        elif isinstance(x, list):
            for i, a in enumerate(x):
                flatten(a, name + str(i) + '_')
        else:
            out.append(str(x))

    flatten(y)
    return ' '.join(out)

def matches_search(flattened_text: str, search_terms: List[str]) -> bool:
    """Check if any of the search terms are in the flattened text."""
    return any(term in flattened_text for term in search_terms)

def curate_json(json_data: List[dict]) -> List[dict]:
    curated_list = []
    for item in json_data:
        flattened_text = flatten_json(item)
        if matches_search(flattened_text, contain):
            curated_item = {}
            for prop in curated_properties:
                value = extract_nested_value(item, prop['property'])
                if value:
                    curated_item[prop['description']] = value
            if curated_item:
                curated_list.append(curated_item)
    return curated_list

def extract_nested_value(data, key_sequence):
    keys = key_sequence.split('.')
    for key in keys:
        data = data.get(key, None)
        if data is None:
            return None
    return data

# Load all JSON files in a directory
directory_path = '/content/drive/MyDrive/FDA_Data_Set'  # Replace with your directory path
all_curated_data = []

for filename in os.listdir(directory_path):
    if filename.endswith('.json'):
        with open(os.path.join(directory_path, filename), 'r') as f:
            data = json.load(f)
            if 'results' in data:
                json_array = data['results']
                curated_data = curate_json(json_array)
                all_curated_data.extend(curated_data)

# Save the final curated JSON array to a file
output_file = '/content/drive/MyDrive/test-extration/curated_data.json'
with open(output_file, 'w') as f:
    json.dump(all_curated_data, f, indent=4)

print(f"Curated data has been saved to {output_file}")
# Out:
# Curated data has been saved to /content/drive/MyDrive/test-extration/curated_data.json

# %% [markdown]
# ## Step 6: Sort An Upload to Upstash Vector Store

# %% [markdown]
# # New Section

# %% [markdown]
# 1. Install Upstash

# %%
# %pip install upstash_vector
# Out:
# Collecting upstash_vector
#   Downloading upstash_vector-0.5.0-py3-none-any.whl.metadata (11 kB)
# Collecting httpx<1,>=0.23.0 (from upstash_vector)
#   Downloading httpx-0.27.0-py3-none-any.whl.metadata (7.2 kB)
# Requirement already satisfied: anyio in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->upstash_vector) (3.7.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->upstash_vector) (2024.7.4)
# Collecting httpcore==1.* (from httpx<1,>=0.23.0->upstash_vector)
#   Downloading httpcore-1.0.5-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: idna in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->upstash_vector) (3.7)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->upstash_vector) (1.3.1)
# Collecting h11<0.15,>=0.13 (from httpcore==1.*->httpx<1,>=0.23.0->upstash_vector)
#   Downloading h11-0.14.0-py3-none-any.whl.metadata (8.2 kB)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio->httpx<1,>=0.23.0->upstash_vector) (1.2.2)
# Downloading upstash_vector-0.5.0-py3-none-any.whl (14 kB)
# Downloading httpx-0.27.0-py3-none-any.whl (75 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 1.1 MB/s eta 0:00:00
# Downloading httpcore-1.0.5-py3-none-any.whl (77 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 2.8 MB/s eta 0:00:00
# Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 3.5 MB/s eta 0:00:00
# Installing collected packages: h11, httpcore, httpx, upstash_vector
# Successfully installed h11-0.14.0 httpcore-1.0.5 httpx-0.27.0 upstash_vector-0.5.0

# %% [markdown]
# 2. Initiate Credentials

# %%
from upstash_vector import Index
from google.colab import userdata

index = Index(url=userdata.get("UPSTASH_VECTOR_REST_URL"), token=userdata.get("UPSTASH_VECTOR_REST_TOKEN"))

# %% [markdown]
# 3. Upsert Data into Upstash (Test)

# %%
import json

# Your JSON object
json_obj = {
    "Drug_Name": ["SPF 50 Mineral Sunscreen Babyganics"],
    "ID": "f3ca0977-4121-4da8-9a14-e4fcdd2e932d",
    "Manufacturer": ["KAS Direct LLC dba BabyGanics"],
    "Purpose": ["Purpose Sunscreen"],
    "Indications_and_Usage": ["Uses helps prevent sunburn if used as directed with"],
    "Active_Ingredients": ["Active ingredients Titanium dioxide 3%, Zinc oxide 12%"],
    "do_not_USE": ["Do not use on damaged or broken skin"],
    "STOP_USE": ["Stop use and ask a doctor if rash occurs"],
    "DOSAGE_INSTRUCTION": ["Directions apply liberally 15 minutes"],
    "Storage_Information": ["Other information protect this product from excessive heat and direct sun"]
}

# Extract values
id_value = json_obj["ID"]
metadata_field = {
    "ID": json_obj["ID"],
    "Drug_Name": json_obj["Drug_Name"][0],
    "Manufacturer": json_obj["Manufacturer"][0]
}
raw_data = json.dumps({k: ', '.join(v) if isinstance(v, list) else v for k, v in json_obj.items() if k != "ID"})

# Prepare data for upsert
index.upsert(
    vectors=[
        (id_value, raw_data, metadata_field),
    ]
)
# Out:
# 'Success'

# %% [markdown]
# 4. Dump All Data Into Vector Store

# %%
import json

json_file_path = '/content/drive/MyDrive/test-extration/curated_data.json'

# Open and read the JSON file
with open(json_file_path, 'r') as file:
    json_array = json.load(file)


# Optional: start from a certain point with id
start_index = 20774

new_array = json_array[start_index:]

# Iterate over each object in the array
for current_index,obj in enumerate(new_array):
    # Extract values
    id_value = obj["ID"]
    metadata_field = {
        "ID": obj["ID"],
        "Drug_Name": obj.get("Drug_Name", [""])[0] if obj.get("Drug_Name") else "", # Use get() with a default value
        "Manufacturer": obj.get("Manufacturer", [""])[0] if obj.get("Manufacturer") else "" # Use get() with a default value
    }

    # Remove brackets by joining the list items into a single string
    raw_data = json.dumps({k: ', '.join(v) if isinstance(v, list) else v for k, v in obj.items() if k != "ID"})

    # Prepare data for upsert
    index.upsert(
        vectors=[
            (id_value, raw_data, metadata_field),
        ]
    )
    print(f"Finish Stashing {obj['ID']}, done {current_index} of {len(json_array)} ")
# Out:
# Streaming output truncated to the last 5000 lines.
# Finish Stashing 204387c0-3dc3-98ec-e063-6394a90ace04, done 24021 of 49795
# Finish Stashing 2047cee4-f8da-9a38-e063-6394a90ac921, done 24022 of 49795
# Finish Stashing addd1856-65cc-46da-a49f-f0b5a99ec5ca, done 24023 of 49795
# Finish Stashing c732aeb0-c867-9e33-e053-2a95a90a129e, done 24024 of 49795
# Finish Stashing 0d98477b-aa34-ebb7-e063-6294a90a597f, done 24025 of 49795
# Finish Stashing 1bc7f2f9-1698-53c7-e063-6394a90a61dc, done 24026 of 49795
# Finish Stashing 59af2008-8ecb-468c-8127-5656cda70c1f, done 24027 of 49795
# Finish Stashing e3ae7662-8e5e-430f-b07d-5c83826fde04, done 24028 of 49795
# Finish Stashing 1e85b0de-e071-00b1-e063-6294a90ace4f, done 24029 of 49795
# Finish Stashing 1f7f09d6-4768-3535-e063-6394a90a8b3b, done 24030 of 49795
# Finish Stashing 202ffb02-d83f-8658-e063-6394a90a2ccc, done 24031 of 49795
# Finish Stashing 3feaf33d-3922-44f5-a298-b7e35c545a7e, done 24032 of 49795
# Finish Stashing 472b0b58-519d-4d12-8881-2243915e8d9e, done 24033 of 49795
# Finish Stashing 1f663002-c5f8-51be-e063-6394a90a997f, done 24034 of 49795
# Finish Stashing 202f58bc-b20f-0b06-e063-6294a90a5e94, done 24035 of 49795
# Finish Stashing 1f764d21-1aa8-0553-e063-6294a90afdbe, done 24036 of 49795
# Finish Stashing 1f91a77b-fe36-676a-e063-6394a90ae03e, done 24037 of 49795
# Finish Stashing 200d9d96-4cf9-4a4d-e063-6294a90ad0a0, done 24038 of 49795
# Finish Stashing 39bb0f2f-1935-466f-aa4b-d60b0cb1c211, done 24039 of 49795
# Finish Stashing 1f44e7f0-4bf3-0e08-e063-6394a90a8473, done 24040 of 49795
# Finish Stashing f82c4c19-c31c-55d8-e053-6294a90a9c3b, done 24478 of 49795
# Finish Stashing 0051c7de-8a83-0905-e063-6294a90a0bec, done 24479 of 49795
# Finish Stashing 003b64cb-732f-b46f-e063-6294a90acb05, done 24480 of 49795
# Finish Stashing 003799f9-5088-876f-e063-6294a90a3fc7, done 24481 of 49795
# Finish Stashing 003a0d9f-65ab-319d-e063-6394a90a6a7e, done 24482 of 49795
# Finish Stashing 003a6ff4-44c6-0cb3-e063-6294a90a6f4a, done 24483 of 49795
# Finish Stashing 003895b4-0e3b-d200-e063-6394a90a1a23, done 24484 of 49795
# Finish Stashing 003b5ad0-570f-ea98-e063-6394a90a2b72, done 24485 of 49795
# Finish Stashing 0022e63f-614f-29f0-e063-6294a90aff98, done 24486 of 49795
# Finish Stashing 0024a9f1-4d6a-4591-e063-6394a90a9ede, done 24487 of 49795
# Finish Stashing 0024a9f1-4d66-4591-e063-6394a90a9ede, done 24488 of 49795
# Finish Stashing 0024a9f1-4d6b-4591-e063-6394a90a9ede, done 24489 of 49795
# Finish Stashing fe91e020-165b-0b7a-e053-6394a90a800b, done 24490 of 49795
# Finish Stashing fe91dac8-d543-9b91-e053-6394a90a2fc2, done 24491 of 49795
# Finish Stashing ffe8d444-454c-bd49-e053-6294a90ad20f, done 24492 of 49795
# Finish Stashing 6af9bb65-4db7-4833-8ae2-d9f1b9c03412, done 24493 of 49795
# Finish Stashing fe26caf9-8285-cf5d-e053-6394a90a9acc, done 24494 of 49795
# Finish Stashing fe04346f-7bd5-4db7-e053-6294a90a338b, done 24495 of 49795
# Finish Stashing fd6bfc15-3915-e1dd-e053-6294a90a4b64, done 24496 of 49795
# Finish Stashing ba1950cd-e831-4d95-afb7-33301da5aa63, done 24497 of 49795
# Finish Stashing 8bde6e99-16cb-41df-8e0b-d97826addce1, done 24498 of 49795
# Finish Stashing fc7294b5-6fe1-64ec-e053-6294a90a0cbc, done 24499 of 49795
# Finish Stashing af2b8787-5aee-4b15-afe6-65f1beaa0201, done 24500 of 49795
# Finish Stashing fc5cc31c-b374-1abe-e053-6294a90a47f5, done 24501 of 49795
# Finish Stashing 6e693a24-c1c3-4d99-a423-7c11cec028fe, done 24502 of 49795
# Finish Stashing fbfb4a5e-fbde-947a-e053-6294a90a1606, done 24503 of 49795
# Finish Stashing fbfdeb3c-8bfc-6e43-e053-6394a90a2960, done 24504 of 49795
# Finish Stashing fbfc505a-b797-9375-e053-6394a90ac641, done 24505 of 49795
# Finish Stashing fbd19f25-cfde-5bb2-e053-6294a90aa616, done 24506 of 49795
# Finish Stashing fb44e956-e4ff-501a-e053-6294a90a5d70, done 24507 of 49795
# Finish Stashing fad5c21a-2a28-702a-e053-6394a90a2e4a, done 24508 of 49795
# Finish Stashing f3ea3575-3fcb-4b63-9c20-67abe0f03f17, done 24509 of 49795
# Finish Stashing faa5a993-bdf2-088f-e053-6394a90ac0c0, done 24510 of 49795
# Finish Stashing faa5116c-4818-21fc-e053-6294a90aa810, done 24511 of 49795
# Finish Stashing f2f38dd9-20d5-8a84-e053-2a95a90a7ed2, done 24580 of 49795
# Finish Stashing f2f6110c-de3a-8535-e053-2995a90a7622, done 24581 of 49795
# Finish Stashing f2f59f63-fce0-2a80-e053-2995a90ab087, done 24582 of 49795
# Finish Stashing f2e9f62e-22fb-9555-e053-2995a90ae44b, done 24583 of 49795
# Finish Stashing f2b8c004-abc7-015b-e053-2a95a90a40e8, done 24584 of 49795
# Finish Stashing 7ea18e49-4c16-4002-8e8a-36e9539d276e, done 24585 of 49795
# Finish Stashing f2682ce3-8cfa-df80-e053-2a95a90ac08a, done 24586 of 49795
# Finish Stashing f2680582-45d8-5d46-e053-2a95a90a0973, done 24587 of 49795
# Finish Stashing eed661e0-4e00-aaf6-e053-2995a90adc55, done 24588 of 49795
# Finish Stashing 65ab3c53-1f32-4553-8818-86590696cee8, done 24589 of 49795
# Finish Stashing 1f94400b-1e66-45f9-bc6a-83caa2e9dd36, done 24590 of 49795
# Finish Stashing eac362c3-95fe-4916-b408-014484204823, done 24591 of 49795
# Finish Stashing ffbcdaef-9ad8-4a94-8ee2-ced689a31acb, done 24592 of 49795
# Finish Stashing f20c98a8-0bf3-07f4-e053-2a95a90a44ad, done 24593 of 49795
# Finish Stashing 8ddbd870-0a08-4be8-8d59-b56c164cd02f, done 24594 of 49795
# Finish Stashing f9f8ce45-cc62-4715-876e-b4d38c2cc32f, done 24595 of 49795
# Finish Stashing da1ae8e4-1c7a-4ac9-81d6-fca58a944d98, done 24596 of 49795
# Finish Stashing f1f190da-554c-55cb-e053-2a95a90a2871, done 24597 of 49795
# Finish Stashing f1ed5fe0-1f4a-1fcf-e053-2995a90aa9b1, done 24598 of 49795
# Finish Stashing f1ed655a-b1fb-3eeb-e053-2995a90ac51c, done 24599 of 49795
# Finish Stashing f1ec46e5-eeb1-d623-e053-2a95a90a13c3, done 24600 of 49795
# Finish Stashing 6f1e6625-a395-4443-801b-e14337b705ea, done 24601 of 49795
# Finish Stashing f187f843-7a53-847e-e053-2995a90a2392, done 24602 of 49795
# Finish Stashing 741d4a42-da3f-4e2c-93d5-bfffedf0c3f5, done 24603 of 49795
# Finish Stashing f1166cb4-b472-7043-e053-2a95a90a7fa7, done 24604 of 49795
# Finish Stashing f116504f-5d6e-299d-e053-2995a90a7c26, done 24605 of 49795
# Finish Stashing e5c2cbe2-7dbe-0f88-e053-2a95a90a134b, done 24606 of 49795
# Finish Stashing db8b3bd0-0f94-4767-9f3c-887c17951526, done 24607 of 49795
# Finish Stashing dea01567-eab8-4eba-8cbf-a4f150e37955, done 24608 of 49795
# Finish Stashing f05f2b96-79d5-6c12-e053-2a95a90a80c9, done 24609 of 49795
# Finish Stashing f031f307-9f45-61d1-e053-2a95a90a2114, done 24610 of 49795
# Finish Stashing f032a3b2-3d34-d2a0-e053-2995a90aa861, done 24611 of 49795
# Finish Stashing f035e3fa-532a-79d5-e053-2995a90a2e9b, done 24612 of 49795
# Finish Stashing f03141f6-9def-7d57-e053-2995a90a16ae, done 24613 of 49795
# Finish Stashing efd22340-1352-7f33-e053-2995a90abcb8, done 24614 of 49795
# Finish Stashing ef442f36-a45a-70ef-e053-2995a90aa0ed, done 24615 of 49795
# Finish Stashing ef447608-d4dc-d82c-e053-2a95a90ab72f, done 24616 of 49795
# Finish Stashing ea8d652c-1583-4429-9d09-928b215a9275, done 24617 of 49795
# Finish Stashing eea19e7f-66b2-2aa2-e053-2995a90aedb3, done 24618 of 49795
# Finish Stashing e76a4120-f732-a978-e053-2995a90a7ecf, done 24619 of 49795
# Finish Stashing ee8c1a2b-36f0-6fd7-e053-2a95a90a9c01, done 24620 of 49795
# Finish Stashing ee1ad771-9548-4272-e053-2a95a90aacc4, done 24621 of 49795
# Finish Stashing ee1551b3-b33d-91bd-e053-2995a90af487, done 24622 of 49795
# Finish Stashing ee1551b3-b33c-91bd-e053-2995a90af487, done 24623 of 49795
# Finish Stashing edfd9a4a-1179-0902-e053-2a95a90ab8d3, done 24624 of 49795
# Finish Stashing edad357c-0105-418d-e053-2995a90a8860, done 24625 of 49795
# Finish Stashing edbf34dc-07d7-183d-e053-2a95a90ae61f, done 24626 of 49795
# Finish Stashing 2418a2ef-0272-47dc-a2c5-da3e19212493, done 24627 of 49795
# Finish Stashing f6ffc4ce-0b8c-4cc7-a209-ab04df11bd3d, done 24628 of 49795
# Finish Stashing ed86d0bb-9bf2-0cd5-e053-2995a90a45c3, done 24629 of 49795
# Finish Stashing ed77114d-a0c5-d37c-e053-2a95a90a283e, done 24630 of 49795
# Finish Stashing ed7e6738-086c-470e-e053-2a95a90a3a67, done 24631 of 49795
# Finish Stashing ecee3632-9ca2-6e93-e053-2a95a90afb58, done 24632 of 49795
# Finish Stashing ece7cccc-933e-5b84-e053-2a95a90ae392, done 24633 of 49795
# Finish Stashing ecb04a97-493b-b148-e053-2995a90abf15, done 24634 of 49795
# Finish Stashing ec6eacdb-6119-cc0b-e053-2995a90a4a02, done 24635 of 49795
# Finish Stashing ec6d0cc7-ede3-df6e-e053-2a95a90a5786, done 24636 of 49795
# Finish Stashing e9c02b1b-da97-6390-e053-2995a90a6194, done 24637 of 49795
# Finish Stashing fd9b1b64-8b9d-40c0-9ec3-e8855f51f09a, done 24638 of 49795
# Finish Stashing e387e2bf-09c0-2340-e053-2995a90a3623, done 24639 of 49795
# Finish Stashing b1b5626b-fdcf-4088-ba27-5e6c0cd13780, done 24640 of 49795
# Finish Stashing eb5bbc70-dbe0-06a8-e053-2995a90a66c1, done 24641 of 49795
# Finish Stashing eb58d603-a2ee-fd50-e053-2a95a90a0ec9, done 24642 of 49795
# Finish Stashing eb6941cf-882a-7479-e053-2995a90af4ef, done 24643 of 49795
# Finish Stashing ef1520a1-a99e-4474-ac9f-2ca11da4d559, done 24644 of 49795
# Finish Stashing 5ee13c70-d0b3-40dd-9238-12768e7b762c, done 24645 of 49795
# Finish Stashing 8bf55622-87ad-4ad5-924c-df92ca44aae4, done 24646 of 49795
# Finish Stashing e892c0cb-03b5-52da-e053-2995a90a0878, done 24647 of 49795
# Finish Stashing ea27d90a-70ac-667a-e053-2995a90aa322, done 24648 of 49795
# Finish Stashing 4d1c971d-a441-4e4d-8c6f-a239f1c5be9a, done 24649 of 49795
# Finish Stashing e9af9bd4-805e-06f5-e053-2995a90aadc4, done 24650 of 49795
# Finish Stashing e9ab9a03-b9e4-7317-e053-2995a90a9950, done 24651 of 49795
# Finish Stashing e713556e-028d-0f4c-e053-2995a90a9e9f, done 24652 of 49795
# Finish Stashing e97409aa-a5d3-9395-e053-2995a90ab2cc, done 24653 of 49795
# Finish Stashing e895d590-80ad-cc41-e053-2a95a90a7c04, done 24654 of 49795
# Finish Stashing e84146e2-98f1-c75a-e053-2a95a90a05eb, done 24655 of 49795
# Finish Stashing e79d0000-bdcd-b51a-e053-2a95a90a9e71, done 24656 of 49795
# Finish Stashing e831b8e5-6f76-bb61-e053-2a95a90a4cc6, done 24657 of 49795
# Finish Stashing e8207fc8-0b00-430b-e053-2995a90a9610, done 24658 of 49795
# Finish Stashing e80449f4-1554-735f-e053-2a95a90a7a34, done 24659 of 49795
# ...
# Finish Stashing 52087936-7069-4920-8119-a7c4ec162204, done 28808 of 49795
# Finish Stashing 1d815a4d-ebfb-6a64-e063-6294a90af714, done 28809 of 49795
# Finish Stashing 1d8cc295-42dd-705e-e063-6294a90a34cd, done 28810 of 49795
# Finish Stashing 1d62cd51-3ba0-210b-e063-6394a90acd9d, done 28811 of 49795
# Finish Stashing 1d7290d5-ddb7-1895-e063-6294a90aae9c, done 28812 of 49795
# Finish Stashing 7fdf24eb-2642-41c0-bef7-f09b3d5371a6, done 28813 of 49795
# Finish Stashing c27d215a-cce0-43f6-b524-b7914f48dea4, done 28814 of 49795
# Finish Stashing 1be193b6-4c08-4f0a-e063-6394a90a32c7, done 28815 of 49795
# Finish Stashing 1d608c94-1652-f318-e063-6294a90aa11e, done 28816 of 49795
# Finish Stashing 1d6e9687-5883-effd-e063-6294a90ab756, done 28817 of 49795
# Finish Stashing 1d8b4fac-9e4a-85c0-e063-6394a90a287a, done 28818 of 49795
# Finish Stashing 28d9a6bd-8c53-4e11-b1df-05e0f3f61dee, done 28819 of 49795
# Finish Stashing 1d81926a-3dcd-4c4e-e063-6394a90adfeb, done 28820 of 49795
# Finish Stashing d3c8ccf2-3ae4-42e0-9b26-6c364b1af28a, done 28821 of 49795
# Finish Stashing 68f05a78-630b-4fd4-be50-eac52567090b, done 28822 of 49795
# Finish Stashing bdac178f-b728-45b6-e053-2995a90a855e, done 28823 of 49795
# Finish Stashing 1e1e0737-9e5f-c94f-e063-6394a90af49c, done 28824 of 49795
# Finish Stashing 1e101a6e-c121-d2ca-e063-6394a90a7e70, done 28825 of 49795
# Finish Stashing 1e7957e1-d955-44fd-e063-6294a90a2c79, done 28826 of 49795
# Finish Stashing 094ac7f6-f89f-35b6-e063-6294a90afcbc, done 28827 of 49795
# Finish Stashing 1e916b46-fa34-b7ba-e063-6294a90a9b2f, done 28828 of 49795
# Finish Stashing 8ae066b4-4e0a-4f1b-b40c-b0cb4b658d41, done 28997 of 49795
# Finish Stashing c0843363-a5db-7be7-e053-2a95a90ae0d5, done 28998 of 49795
# Finish Stashing fade0d6d-a44e-4a2c-8a2a-4676ec029882, done 28999 of 49795
# Finish Stashing 204bf094-4604-3b8e-e063-6394a90ac725, done 29000 of 49795
# Finish Stashing 7152aa39-2833-41f1-b5dc-34d588a81e3b, done 29001 of 49795
# Finish Stashing cf03a049-0945-478c-95cb-da1f2c878807, done 29002 of 49795
# Finish Stashing b701234a-0bd3-16d3-e053-2995a90a5b13, done 29003 of 49795
# Finish Stashing da833cb5-92ec-28a6-e053-2995a90a8315, done 29004 of 49795
# Finish Stashing 00ecf118-0cb1-61a0-e063-6294a90a9967, done 29005 of 49795
# Finish Stashing 20439c90-1ad1-0f2b-e063-6294a90ad610, done 29006 of 49795
# Finish Stashing 2043dd0c-0fea-73ba-e063-6394a90aa1fd, done 29007 of 49795
# Finish Stashing 2047c9a6-95a4-732a-e063-6394a90a9d86, done 29008 of 49795
# Finish Stashing 1f4593b4-b9c5-f003-e063-6394a90a20e2, done 29009 of 49795
# Finish Stashing 624a21a9-4206-42a2-b105-8164ea525ac8, done 29010 of 49795
# Finish Stashing 7cf345f1-ad2e-e873-e053-2991aa0aa106, done 29011 of 49795
# Finish Stashing a49eb9ec-3698-4e95-8377-a6a2365de9a9, done 29012 of 49795
# Finish Stashing de524b13-051d-4c30-b7d0-ab7572f9a6ab, done 29013 of 49795
# Finish Stashing f482e734-4944-4288-9380-c521b844c4ec, done 29014 of 49795
# Finish Stashing f910cf47-d77f-47cb-9da4-993752ec3969, done 29015 of 49795
# Finish Stashing 06e8bd89-6594-d974-e063-6294a90a66d9, done 29016 of 49795
# Finish Stashing 204a7e15-a7ca-f2b6-e063-6394a90ae9c2, done 29017 of 49795
# Finish Stashing 203779d4-7356-b982-e063-6294a90a5b4d, done 29018 of 49795
# Finish Stashing 2044158c-7bc4-cd0a-e063-6294a90af520, done 29019 of 49795
# Finish Stashing ddbf25ea-80d2-5725-e053-2a95a90abacc, done 29020 of 49795

# %%
# Optional
# get the array starting point

import json

json_file_path = '/content/drive/MyDrive/test-extration/curated_data.json'

# Open and read the JSON file
with open(json_file_path, 'r') as file:
    json_array = json.load(file)

target_id="5de4a406-8d7d-499f-ac4b-4ea088a9680b"

def find_index_by_id(json_array, target_id):
    for index, obj in enumerate(json_array):
        if obj.get('ID') == target_id:
            return index
    return -1  # Return -1 if id not found

index_position = find_index_by_id(json_array, target_id)
print(f"Index position of object with id {target_id}: {index_position}")
# Out:
# Index position of object with id 5de4a406-8d7d-499f-ac4b-4ea088a9680b: 20774

# %% [markdown]
# https://dailymed.nlm.nih.gov/dailymed/fda/fdaDrugXsl.cfm?setid=5453cd31-e70b-4f6c-81ce-206b960a54bc

# %% [markdown]
# ## Section 2: Semantic Router

# %% [markdown]
# This is used to solve the attention issue associated with small context model, by detecting if user has leave the current "subtopic", we can decide whether or not to regenerate the context

# %%
# %pip install -qU semantic-router
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 83.4/83.4 kB 1.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.8/207.8 kB 3.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 362.9/362.9 kB 7.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 18.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.1/139.1 kB 9.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 44.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 5.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 5.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 318.9/318.9 kB 20.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.5/12.5 MB 61.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.7/82.7 kB 5.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 3.7 MB/s eta 0:00:00

# %%
from semantic_router import Route

# use this as a guard rail, we will only allow these two types of conversation
medical = Route(
    name="medical",
    utterances=[
        "Is this effective on fever?",
        "Is Tylenol safe for pregnant women?"
        "When did FDA approve this pill?",
        "What is the chemical composition of this drug?",
        "Is Triptans an OTC medicine?",
        "Are there any safety incidents related to this medication?"
        "What is the toxicity of this tablet?",
        "Do you recommend three dose a day?",
        "Is it legal to buy this drug in Ohio?"
    ],
)

# regular conversation
chitchat = Route(
    name="chitchat",
    utterances=[
        "how's the weather today?",
        "how are things going?",
        "Good Morning",
        "Done anything fun last week?",
        "I hope you have a great day",
        "Have you seen that movie recently?"
    ],
)

# medicine

# we place both of our decisions together into single list
routes = [medical, chitchat]
# Out:
# /usr/local/lib/python3.10/dist-packages/pydantic/_internal/_config.py:341: UserWarning: Valid config keys have changed in V2:
# * 'allow_population_by_field_name' has been renamed to 'populate_by_name'
# * 'smart_union' has been removed
#   warnings.warn(message, UserWarning)

# %%
import os
from semantic_router.encoders import CohereEncoder, OpenAIEncoder
from google.colab import userdata



# for Cohere
# os.environ["COHERE_API_KEY"] = "<YOUR_API_KEY>"
# encoder = CohereEncoder()

# or for OpenAI
os.environ["OPENAI_API_KEY"] = userdata.get("OPENAI_API_KEY")
encoder = OpenAIEncoder()

# %%
from semantic_router.layer import RouteLayer

rl = RouteLayer(encoder=encoder, routes=routes)

# %%
# @title Default title text
chathistory = [
    # Unrelated (Normal - Notify)
    "Marvel doesn't produce good movie these day right?",
    "Just checking on you",
    "Is 'Dosing with life' a good YouTube channel?",
    "This soup taste good!",
    # Normal
    "What would happen to me if I take 3 instead of 1 every day?"
    "Dude drug his dog. What a scum!",
    "His pen has surgical precision",
    "A doctor slice up his belly",
    "Should I go to hospital?",
    # Warn (Switch Topic)
    "How strong is this drug?",
    "Morphine has some strange effect on me",
    ""
    # Disengage (Stop)
    "Fentanyl and Heroin, which one can get me high",
    "I want to kill myself",
    "I want to stab you!",
    "You son of bitch",
    "Stupid mother fucker!"
]
for i in chathistory:
  topic = rl(i).name
  print(i+" => ")
  print(topic)
#  rl("saw some be").name
# print(topic)
# Out:
# chitchat
# chitchat
# medical
# medical
# None
# None
# None
# None
# medical
# None
# None
# None
# None

# %% [markdown]
# ## Use semantic router to check if topic Switch from last
#
# 1. First prepare a set of data as sample, cover wide range of medical/medicine related discussion
#
#
# *   Can ask LLM to generate
# *   Output into an array
#
#
#
# 2. Pass *first user prompt* into the layer, measure the `similarity_score`
# 3. Keep passing, and monitor the `z-score` / `Rolling Standard Deviation`
# 4. Is there a more effcient way? Maybe try the built-in `conversation` in `semantic-router` as well? Need to assess both options

# %% [markdown]
# ### Use SR to Create Tool Function Calls for Agents
#
# 1. OutSource => list Websites, use Google API to fetch
# 2. Meditate => Summon a Widget to
# 3. Med Stock => Check the Stock price of popular medical company
# 4. Graph => Create Relationship Diagram
